# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# flatten 28*28 images to a 784 vector for each image
num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape((X_train.shape[0], num_pixels)).astype('float32')
X_test = X_test.reshape((X_test.shape[0], num_pixels)).astype('float32')
# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]
# define baseline model
def baseline_model():
# create model
    model=Sequential()
    model.add(Dense(num_pixels, input_dim=num_pixels, kernel_initializer='normal', activation='relu'))
    model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
# Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
# build the model
model = baseline_model()
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
print(scores)
# Out:
# Epoch 1/10
# 300/300 - 3s - loss: 0.2764 - accuracy: 0.9221 - val_loss: 0.1372 - val_accuracy: 0.9586
# Epoch 2/10
# 300/300 - 3s - loss: 0.1090 - accuracy: 0.9683 - val_loss: 0.0921 - val_accuracy: 0.9729
# Epoch 3/10
# 300/300 - 3s - loss: 0.0716 - accuracy: 0.9788 - val_loss: 0.0782 - val_accuracy: 0.9768
# Epoch 4/10
# 300/300 - 3s - loss: 0.0494 - accuracy: 0.9859 - val_loss: 0.0699 - val_accuracy: 0.9779
# Epoch 5/10
# 300/300 - 3s - loss: 0.0359 - accuracy: 0.9902 - val_loss: 0.0702 - val_accuracy: 0.9777
# Epoch 6/10
# 300/300 - 3s - loss: 0.0266 - accuracy: 0.9929 - val_loss: 0.0638 - val_accuracy: 0.9790
# Epoch 7/10
# 300/300 - 3s - loss: 0.0187 - accuracy: 0.9956 - val_loss: 0.0654 - val_accuracy: 0.9806
# Epoch 8/10
# 300/300 - 3s - loss: 0.0146 - accuracy: 0.9969 - val_loss: 0.0645 - val_accuracy: 0.9799
# Epoch 9/10
# 300/300 - 3s - loss: 0.0108 - accuracy: 0.9978 - val_loss: 0.0600 - val_accuracy: 0.9824
# Epoch 10/10
# 300/300 - 3s - loss: 0.0072 - accuracy: 0.9990 - val_loss: 0.0590 - val_accuracy: 0.9824
# Baseline Error: 1.76%
# [0.059037353843450546, 0.9824000000953674]
